# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Phone_Details.xlsx')
df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043   1.0          1.8         1  14       0         5.0
# 1   2            841   1.0          0.5         1   4       1        61.0
# 2   3           1807   1.0          2.8         0   1       0        27.0
# 3   4           1546   0.0          0.5         1  18       1        25.0
# 4   5           1434   0.0          1.4         0  11       1        49.0
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df.shape
# Out:
# (3000, 21)

# %%
df.isnull().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
df.drop(columns=['id'])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              1043   1.0          1.8         1  14       0         5.0
# 1               841   1.0          0.5         1   4       1        61.0
# 2              1807   1.0          2.8         0   1       0        27.0
# 3              1546   0.0          0.5         1  18       1        25.0
# 4              1434   0.0          1.4         0  11       1        49.0
# ...             ...   ...          ...       ...  ..     ...         ...
# 2995              1   0.5          0.0         6   0      26         0.2
# 2996              0   2.5          0.0         5   1      51         0.4
# 2997              1   2.8          1.0         0   1       7         0.1
# 2998              1   1.8          1.0         1   0      40         0.5
# 2999              1   1.2          0.0         8   0      31         0.6
#
#       m_dep  mobile_wt  n_cores   pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                 count         mean          std    min      25%     50%  \
# id             3000.0   992.512333   526.848699    1.0   601.00   913.5
# battery_power  3000.0   416.500000   639.166930    0.0     0.00     1.0
# blue           3000.0     1.186833     0.867291    0.0     0.50     1.0
# clock_speed    3000.0     0.853300     0.795118    0.0     0.00     1.0
# dual_sim       3000.0     3.045333     3.980439    0.0     0.00     1.0
# fc             3000.0     1.878667     3.238432    0.0     0.00     1.0
# four_g         3000.0    21.526667    20.999181    0.0     1.00    16.0
# int_memory     3000.0    11.551833    18.810166    0.1     0.40     0.8
# m_dep          3000.0    93.671833    71.941799    0.1     0.80   109.0
# mobile_wt      3000.0    49.517333    66.774816    1.0     4.00     7.0
# n_cores        3000.0     8.053667     5.761931    0.0     3.00     7.0
# pc             3000.0   433.423333   470.037698    0.0    15.00   282.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             3000 non-null   int64
#  1   battery_power  3000 non-null   int64
#  2   blue           3000 non-null   float64
#  3   clock_speed    3000 non-null   float64
#  4   dual_sim       3000 non-null   int64
#  5   fc             3000 non-null   int64
#  6   four_g         3000 non-null   int64
#  7   int_memory     3000 non-null   float64
#  8   m_dep          3000 non-null   float64
#  9   mobile_wt      3000 non-null   int64
#  10  n_cores        3000 non-null   int64
#  11  pc             3000 non-null   int64
#  12  px_height      3000 non-null   int64
#  13  px_width       3000 non-null   int64
#  14  ram            3000 non-null   int64
#  15  sc_h           3000 non-null   int64
#  16  sc_w           3000 non-null   int64
# ...

# %%
df.corr()
# Out:
#                      id  battery_power      blue  clock_speed  dual_sim  \
# id             1.000000      -0.610675  0.367343    -0.411723  0.316844
# battery_power -0.610675       1.000000 -0.509638     0.553858 -0.415284
# blue           0.367343      -0.509638  1.000000    -0.328114  0.245171
# clock_speed   -0.411723       0.553858 -0.328114     1.000000 -0.288597
# dual_sim       0.316844      -0.415284  0.245171    -0.288597  1.000000
# fc            -0.385896       0.543268 -0.343266     0.367588 -0.264821
# four_g         0.466206      -0.652537  0.391157    -0.439250  0.300036
# int_memory    -0.550970       0.765763 -0.456971     0.497835 -0.373779
# m_dep          0.605323      -0.843055  0.504765    -0.561897  0.419829
# mobile_wt     -0.630797       0.871926 -0.519157     0.580020 -0.428542
# n_cores        0.319264      -0.418686  0.246938    -0.288928  0.698593
# pc             0.428544      -0.586395  0.339797    -0.397636  0.279340
# ...

# %%
sns.scatterplot(x=df['wifi'],y=df['clock_speed'])
plt.title("Distibution of wifi and clock speed")
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.scatterplot(x=df['px_width'],y=df['px_height'],hue=df['wifi'],palette='summer')
plt.title("Distibution of width and height")
plt.show()

# %%
sns.histplot(df['dual_sim'],kde=True)
plt.title("Dual sim distribution")
plt.show()

# %%
sns.countplot(x=df['three_g'],color='orange')
plt.title('Distribution of Three G')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df['int_memory'],y=df['clock_speed'],hue=df['n_cores'],palette='coolwarm')
plt.title("Distribution of clock speed")
plt.show()

# %%
df_filt = df[df['pc']>250]
sns.histplot(df_filt['pc'],kde=True)
plt.show()

# %%
df_filt = df[df['ram']>250]
sns.histplot(df_filt['ram'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),cmap='summer',annot=True)
plt.title("Correlation heatmap")
plt.show()
